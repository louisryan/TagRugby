# %%
from bs4 import BeautifulSoup
import urllib2, re
from dateutil import parser
import mysql.connector as sql

# %%
def make_soup(my_url_not_defined) :
    html = urllib2.urlopen(url).read()
    return BeautifulSoup(html)

# %%
url = "http://www.premierleague.com/content/premierleague/en-gb/matchday/matches.html"
soup = make_soup(url)
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html class="no-js">
#  <head>
#   <meta content="chrome=1;IE=9; IE=8; IE=7; IE=EDGE" http-equiv="X-UA-Compatible"/>
#   <meta content="/etc/designs/premierleague/images/premierleague-logo.png" property="og:image"/>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="" http-equiv="keywords"/>
#   <meta content="Check the forthcoming Barclays Premier League fixtures for your club, at the official website of the Premier League." http-equiv="description"/>
#   <script src="/etc/designs/premierleague/modernizr.js" type="text/javascript">
#   </script>
#   <script src="/etc/designs/premierleague/exlibs.js" type="text/javascript">
#   </script>
#   <link href="/etc/designs/premierleague/exlibs.css" rel="stylesheet" type="text/css"/>
#   <script src="/etc/designs/premierleague/clientlibs.js" type="text/javascript">
#   </script>
#   <link href="/etc/designs/premierleague/clientlibs.css" rel="stylesheet" type="text/css"/>
#   <!--[if lte IE 7]>
#     <script type="text/javascript" src="/etc/designs/premierleague/ie7down.js"></script>
# <link rel="stylesheet" href="/etc/designs/premierleague/ie7down.css" type="text/css">
#
# <![endif]-->
#   <!--[if IE 8]>
#     <script type="text/javascript" src="/etc/designs/premierleague/ie8.js"></script>
# <link rel="stylesheet" href="/etc/designs/premierleague/ie8.css" type="text/css">
#
# <![endif]-->
#   <!--[if IE 9]>
#     <script type="text/javascript" src="/etc/designs/premierleague/ie9.js"></script>
# <link rel="stylesheet" href="/etc/designs/premierleague/ie9.css" type="text/css">
#
# <![endif]-->
#   <link href="/etc/designs/premierleague.css" rel="stylesheet" type="text/css"/>
#   <script src="/etc/designs/premierleague/fixtures.js" type="text/javascript">
#   </script>
#   <link href="/etc/designs/premierleague/fixtures.css" rel="stylesheet" type="text/css"/>
#   <!-- GA Base Tag 20120807 -->
#   <script type="text/javascript">
#    var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', "UA-33785302-1"]);
#   _gaq.push(['_setDomainName', 'premierleague.com']);
#   _gaq.push(['_addIgnoredRef', 'premierleague.com']);
#   _gaq.push(['_setAllowLinker', true]);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#   </script>
#   <!-- End GA Base Tag -->
#   <!-- Dynamic Exit, Download, Mailto GA Extension -->
#   <script language="javascript" src="/etc/designs/premierleague/clientlibs/js/ga_extensions.js" type="text/javascript">
#   </script>
#   <!-- Lotame Header Tag -->
#   <script type="text/javascript">
#    var cc_client_id=3150;
# document.write('<scr'+'ipt type="text/javascript" src="http://ad.crwdcntrl.net/5/c='+cc_client_id.toString()+'/pe=y/callback=processauds"></scr'+'ipt>');
# var adtechCCvals = "";
# function processauds(adtechccauds) {
# if (typeof(adtechccauds) != 'undefined'){
# for (var cci = 0; cci < adtechccauds.Profile.Audiences.Audience.length;cci++){
# if (cci > 0) adtechCCvals += ":";
# adtechCCvals +=adtechccauds.Profile.Audiences.Audience[cci].abbr;
# }
# }
# }
#   </script>
#   <script language="javascript">
#    &lt;!--document.write('&lt;scr'+'ipt language="javascript1.1" src="http://adserver.adtech.de/addyn/3.0/327.0/3052915/0/0/ADTECH;loc=100;target=_blank;sub1=[subst];key=key1+key2+key3+key4;grp=[group];KVabbr='+window.adtechCCvals+';misc='+new Date().getTime()+';rdclick="&gt;&lt;/scri'+'pt&gt;');//--&gt;
#   </script>
#   <!-- end of Lotame Header Tag -->
#   <title>
#    Fixtures | Barclays Premier League football fixture list, season 2014/15 matches
#   </title>
#  </head>
#  <body>
#   <div class="pagedata">
#   </div>
#   <div class="parsys iparsys floatingbar-ipsys">
#    <div class="section">
#     <div class="new">
#     </div>
#    </div>
#    <div class="iparys_inherited">
#     <div class="parsys iparsys floatingbar-ipsys">
#      <div class="section">
#       <div class="parbase codeinsert">
#        <style>
#         .search-results .resultsList .resultsImage {
# background-size:45px !important;
# }
# .latestnewfeatures .first img.thumb, .latestnews .sub .thumb {
# width: 45px;
# }
#        </style>
#        <!-- FLOATING BANNER AD -->
#        <style>
#         .ad_floating_bar {
# 	    bottom: 0;
# 	    display: none;
# 	    left: 0;
# 	    margin: 0;
# 	    padding: 0;
# 	    position: fixed;
# 	    width: 100%;
# 	    z-index: 1010;
# 	}
#
# 	.ad_floating_bar .inner-container {
# 	    height: 50px;
# 	    margin: 0 auto;
# 	    position: relative;
# 	    width: 940px;
# 	}
#
# 	.ad_floating_bar .close {
# 	    background: url("/etc/designs/premierleague/images/home/brick/close-cross.png") no-repeat scroll center center #44445E;
# 	    background-size:12px 12px;
# 	    cursor: pointer;
# 	    display: block;
# 	    height: 16px;
# 	    position: absolute;
# 	    right: 0px;
# 	    top: 0px;
# 	    width: 16px;
# 	    z-index: 1011;
# 	}
#
# .persistent-menu_account {
#     display: none;
# }
#        </style>
#        <div class="ad_floating_bar clearfix" data-adtech="adtech-floating">
#         <div class="inner-container">
#          <span class="close">
#          </span>
#          <!--JavaScript Tag // Tag for network 327: Perform // Website: Premier League 2013 // Page: Homepage // Placement: Home Page-Floating Bar-1 x 1 (4799947) // created at: Sep 10, 2013 11:49:01 AM-->
#          <script language="javascript">
#           function isDesktopMode() {
# 				if (screen.width >= 940) {
# 					return true;
# 				}
# 				return false;	// iPad mode
# 			}
#
# 			function floatingBarAd() {
#        			if (window.adgroupid == undefined) {
# 					window.adgroupid = Math.round(Math.random() * 1000);
# 				}
#
#        			//alert('isDesktop: ' + isDesktopMode() + ', screenWidth:' + screen.width);
#
# 				return '<scr'+'ipt language="javascript1.1" src="http://adserver.adtech.de/addyn|3.0|327|4799947|0|16|ADTECH;cookie=info;kvlayout=' + ((isDesktopMode()) ? 'wide' : 'narrow') + ';kvskin=' + ((isDesktopMode()) ? 'yes' : 'no') + ';loc=100;target=_blank;sub1=[subst];grp='+window.adgroupid+';misc='+new Date().getTime()+'"></scri'+'pt>';
# 			}
#          </script>
#          <noscript>
#           <img border="0" height="1" src="http://adserver.adtech.de/adserv|3.0|327|4799947|0|16|ADTECH;cookie=info;loc=300" width="1"/>
#          </noscript>
#          <!-- End of JavaScript Tag -->
#          <div id="floating_bar_adtech_container">
#           <script type="text/javascript">
#            (function(){
#                     var el = $('.ad_floating_bar');
#                     if (el) {
#                         var cookie_name = 'sw_no_ad_floating_bar';
#                         if (!$.cookie(cookie_name)) {
#                             if (typeof floatingBarAd != 'undefined') {
#                                 var text = floatingBarAd();
#                                 document.write(text);
#
#                                 // only show banner div if Ad content exists
#                                 setTimeout(function(){
#                                 	var adExists = false;
#                                 	var isFlash = false;
#
#                                 	var addContent = $("#floating_bar_adtech_container").children("div");
#                                     if (addContent && addContent.length > 0){
#                                     	adExists = true;
#                                     } else {
#                                     	addContent = $("#floating_bar_adtech_container").children("a");
#                                     	if (addContent && addContent.length > 0){
#                                             adExists = true;
#                                         } else {
#                                             addContent = $("#floating_bar_adtech_container").children("object");
#                                             if (addContent && addContent.length > 0){
#                                                 adExists = true;
#                                                 isFlash = true;
#                                             }
#                                         }
#                                     }
#                                     //alert('adExists:' + adExists);
#
#                                     if (adExists) {
#                                     	// display:none stops flash objects from loading
#                                     	// so show if flash, or not a 1x1 Ad
#                                     	if (isFlash || addContent[0].width > 1 || addContent[0].firstChild.naturalWidth > 1) {
#                                     		el.css({display:'block'});
#
#                                     		// adjust width if iPad mode
#                                         	if (!isDesktopMode()) {
#                                         		$('.inner-container').css({width:'660px'});
#                                         	}
#                                     	}
#                                     }
#                                 },2000); //Adjust the timeout interval to broadcast ads more accurately
#                                 $('.ad_floating_bar .close').bind('click', function(evt){
#                                     el.css({display:'none'});
#
#                                     var date = new Date();
#                                     date.setTime(date.getTime()+(24*60*60*1000)); // 24h
#                                     document.cookie = cookie_name + "=1; expires=" + date.toUTCString() + "; path=/; domain=.premierleague.com;";
#                                     Event.stop(evt);
#                                 });
#                             }
#                         }
#                     }
#                 })();
#           </script>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <h1 class="seo">
#   </h1>
#   <div id="cookies-verify" widget="siteCookies">
#    <div id="cookies-verify-prompt">
#     <span>
#      Cookies on Premierleague.com
#     </span>
#     <p>
#      The Premier League website employs cookies to improve your user experience. We have updated
#      <strong>
#       <a href="/content/premierleague/en-gb/toolbar/cookie-policy">
#        our cookie policy
#       </a>
#      </strong>
#      to reflect changes in the law on cookies and tracking technologies used on websites. If you continue on this website, you will be providing your consent to our use of cookies.
#      <strong>
#       <a href="/content/premierleague/en-gb/toolbar/cookie-policy">
#        Find out more
#       </a>
#      </strong>
#      .
#     </p>
#    </div>
#   </div>
#   <div id="header" widget="pinning">
#    <div id="masthead">
#     <div class="banner">
#      <div class="banner-inner">
#       <div class="parsys iparsys bannersys">
#        <div class="section">
#         <div class="new">
#         </div>
#        </div>
#        <div class="iparys_inherited">
#         <div class="parsys iparsys bannersys">
#          <div class="section">
#           <div class="parbase bannerad">
#            <script type="text/javascript">
#             if (window.adgroupid == undefined) {
#       window.adgroupid = Math.round(Math.random() * 1000);
#   }
#   document.write('<scr'+'ipt type="text/javascript" src="http://adserver.adtech.de/addyn|3.0|327|4806596|0|225|ADTECH;cookie=info;loc=100;target=_blank;sub1=[subst];grp='+window.adgroupid+';KVabbr='+window.adtechCCvals+';misc='+new Date().getTime()+'"></scri'+'pt>');
#            </script>
#            <noscript>
#             <img border="0" height="90" src="http://adserver.adtech.de/adserv|3.0|327|4806596|0|225|ADTECH;cookie=info;loc=300" width="728"/>
#            </noscript>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#     <!-- Custom Effective Measure Tag Code -->
#     <script type="text/javascript">
#      (function() {
#     var em = document.createElement('script'); em.type = 'text/javascript'; em.async = true;
#     em.src = ('https:' == document.location.protocol ? 'https://me-ssl' : 'http://me-cdn') + '.effectivemeasure.net/em.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(em, s);
#   })();
#     </script>
#     <noscript>
#      <img alt="" src="//me.effectivemeasure.net/em_image" style="position:absolute; left:-5px;"/>
#     </noscript>
#     <div class="sitehead">
#      <div class="utils">
#       <div class="logo">
#        <a href="/en-gb.html" title="Home">
#         <span>
#          Barclays Premier League
#         </span>
#        </a>
#       </div>
#       <div class="links clearfix siteutils">
#        <div class="clublogos">
#         <ul>
#          <li class="logo0">
#           <a href="/en-gb/clubs/profile.overview.html/arsenal" title="Arsenal">
#            <span>
#             Arsenal
#            </span>
#           </a>
#          </li>
#          <li class="logo1">
#           <a href="/en-gb/clubs/profile.overview.html/aston-villa" title="Aston Villa">
#            <span>
#             Aston Villa
#            </span>
#           </a>
#          </li>
#          <li class="logo2">
#           <a href="/en-gb/clubs/profile.overview.html/burnley" title="Burnley">
#            <span>
#             Burnley
#            </span>
#           </a>
#          </li>
#          <li class="logo3">
#           <a href="/en-gb/clubs/profile.overview.html/chelsea" title="Chelsea">
#            <span>
#             Chelsea
#            </span>
#           </a>
#          </li>
#          <li class="logo4">
#           <a href="/en-gb/clubs/profile.overview.html/crystal-palace" title="Crystal Palace">
#            <span>
#             Crystal Palace
#            </span>
#           </a>
#          </li>
#          <li class="logo5">
#           <a href="/en-gb/clubs/profile.overview.html/everton" title="Everton">
#            <span>
#             Everton
#            </span>
#           </a>
#          </li>
#          <li class="logo6">
#           <a href="/en-gb/clubs/profile.overview.html/hull" title="Hull City">
#            <span>
#             Hull City
#            </span>
#           </a>
#          </li>
#          <li class="logo7">
#           <a href="/en-gb/clubs/profile.overview.html/leicester" title="Leicester City">
#            <span>
#             Leicester City
#            </span>
#           </a>
#          </li>
#          <li class="logo8">
#           <a href="/en-gb/clubs/profile.overview.html/liverpool" title="Liverpool">
#            <span>
#             Liverpool
#            </span>
#           </a>
#          </li>
#          <li class="logo9">
#           <a href="/en-gb/clubs/profile.overview.html/man-city" title="Manchester City">
#            <span>
#             Manchester City
#            </span>
#           </a>
#          </li>
#          <li class="logo10">
#           <a href="/en-gb/clubs/profile.overview.html/man-utd" title="Manchester United">
#            <span>
#             Manchester United
#            </span>
#           </a>
#          </li>
#          <li class="logo11">
#           <a href="/en-gb/clubs/profile.overview.html/newcastle" title="Newcastle United">
#            <span>
#             Newcastle United
#            </span>
#           </a>
#          </li>
#          <li class="logo12">
#           <a href="/en-gb/clubs/profile.overview.html/qpr" title="Queens Park Rangers">
#            <span>
#             Queens Park Rangers
#            </span>
#           </a>
#          </li>
#          <li class="logo13">
#           <a href="/en-gb/clubs/profile.overview.html/southampton" title="Southampton">
#            <span>
#             Southampton
#            </span>
#           </a>
#          </li>
#          <li class="logo14">
#           <a href="/en-gb/clubs/profile.overview.html/stoke" title="Stoke City">
#            <span>
#             Stoke City
#            </span>
#           </a>
#          </li>
#          <li class="logo15">
#           <a href="/en-gb/clubs/profile.overview.html/sunderland" title="Sunderland">
#            <span>
#             Sunderland
#            </span>
#           </a>
#          </li>
#          <li class="logo16">
#           <a href="/en-gb/clubs/profile.overview.html/swansea" title="Swansea City">
#            <span>
#             Swansea City
#            </span>
#           </a>
#          </li>
#          <li class="logo17">
#           <a href="/en-gb/clubs/profile.overview.html/spurs" title="Tottenham Hotspur">
#            <span>
#             Tottenham Hotspur
#            </span>
#           </a>
#          </li>
#          <li class="logo18">
#           <a href="/en-gb/clubs/profile.overview.html/west-brom" title="West Bromwich Albion">
#            <span>
#             West Bromwich Albion
#            </span>
#           </a>
#          </li>
#          <li class="logo19">
#           <a href="/en-gb/clubs/profile.overview.html/west-ham" title="West Ham United">
#            <span>
#             West Ham United
#            </span>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <div class="siteutilshead">
#         <ul class="primary">
#          <h2>
#           <span>
#           </span>
#          </h2>
#          <li class="tickets">
#           <a href="/en-gb/matchday/tickets.html">
#            Tickets
#           </a>
#          </li>
#          <li class="broadcast">
#           <a href="/en-gb/matchday/broadcast-schedules.html">
#            Broadcast Schedules
#           </a>
#          </li>
#          <li class="fpl">
#           <a href="http://fantasy.premierleague.com">
#            Fantasy Premier League
#           </a>
#          </li>
#         </ul>
#        </div>
#       </div>
#      </div>
#     </div>
#     <div class="fixtures-container">
#      <div class="fixtures">
#       <div id="megamenu-container">
#        <div class="parsys iparsys headersys">
#         <div class="section">
#          <div class="new">
#          </div>
#         </div>
#         <div class="iparys_inherited">
#          <div class="parsys iparsys headersys">
#           <div class="section">
#            <div class="parbase persistentnavigation">
#             <script src="http://w.sharethis.com/button/buttons.js" type="text/javascript">
#             </script>
#             <script type="text/javascript">
#              stLight.options({ publisher:'c42f5e69-5de0-4112-8137-445557383944', doNotHash: true, doNotCopy: true, hashAddressBar: false });
#             </script>
#             <script>
#              (function(d, s, id) { var js, fjs = d.getElementsByTagName(s)[0]; if (d.getElementById(id)) return; js = d.createElement(s); js.id = id; js.src = "//connect.facebook.net/en_GB/all.js#xfbml=1"; fjs.parentNode.insertBefore(js, fjs); }(document, 'script', 'facebook-jssdk'));
#             </script>
#             <script>
#              !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src="//platform.twitter.com/widgets.js";fjs.parentNode.insertBefore(js,fjs);}}(document,"script","twitter-wjs");
#             </script>
#             <div class="ct-wrapper" widget="persistentWidget">
#              <div class="persistent-menu">
#               <ul>
#                <li autoheight="true" class="persistent-menu_account" id="persistent_login" mediatype="html" modalheight="500" modalwidth="535" onauthsuccess="/content/premierleague/en-gb/matchday/matches.html" widget="mediamodal" windowbgcolor="transparent" windowclass="login" windowsourceid="#login_modal">
#                 <a href="https://users.premierleague.com/PremierUser/account/login.html">
#                  Login/ Register
#                 </a>
#                </li>
#                <li class="persistent-menu_account" id="persistent_account">
#                 <a href="https://users.premierleague.com/PremierUser/account/my-account.html">
#                  My Account
#                 </a>
#                </li>
#                <li class="persistent-menu_account" id="persistent_logout">
#                 <a href="https://users.premierleague.com/PremierUser/j_spring_security_logout">
#                  Logout
#                 </a>
#                </li>
#               </ul>
#               <ul class="persistent-menu_tools">
#                <li>
#                 <a class="persistent-menu_tools_search" id="sitesearch-btn" searchmodal="#search-modal" widget="siteSearchModal">
#                 </a>
#                </li>
#                <li>
#                 <span class="st_sharethis_vcount persistent-menu_tools_share" displaytext="ShareThis">
#                 </span>
#                </li>
#               </ul>
#               <ul class="persistent-menu_share-links">
#                <li>
#                 <div class="fb-like" data-href="http://facebook.com/premierleague" data-layout="box_count" data-send="false" data-show-faces="false" data-width="100">
#                 </div>
#                </li>
#                <li>
#                 <div class="twitter_box">
#                  <span id="followers">
#                   4.9M
#                  </span>
#                 </div>
#                 <a class="twitter-follow-button" data-align="left" data-show-count="false" data-show-screen-name="false" href="https://twitter.com/premierleague">
#                 </a>
#                </li>
#                <li>
#                 <a class="ig-b- ig-b-32" href="http://instagram.com/premierleague?ref=badge">
#                 </a>
#                </li>
#               </ul>
#               <div class="parbase login">
#                <div id="login_modal">
#                 <div class="logo-bar">
#                  <div class="logo">
#                  </div>
#                  <div class="logo-background">
#                  </div>
#                 </div>
#                 <div class="login_wrapper">
#                  <div class="titlebar">
#                   <h4>
#                    LOGIN TO YOUR ACCOUNT
#                   </h4>
#                  </div>
#                  <div class="content">
#                   <form action="https://users.premierleague.com/PremierUser/restLogin" id="login_form" method="post" name="login_form" reactivate="https://users.premierleague.com/PremierUser/account/re-register.html" widget="loginmodal">
#                    <div class="errormsg">
#                     <h5 class="error_title">
#                      OOPS!
#                     </h5>
#                     <p>
#                      Please check the following:
#                     </p>
#                     <p class="msg">
#                      ‘
#                      <span>
#                       *
#                      </span>
#                      ’ does not appear to be registered or password was incorrect
#                     </p>
#                    </div>
#                    <fieldset class="fields">
#                     <div class="email row">
#                      <input class="required email" id="login_email" name="email" placeholder="Enter your e-mail" type="text"/>
#                     </div>
#                     <div class="password row">
#                      <input class="required password" id="login_password" name="password" placeholder="Enter your password" type="password"/>
#                     </div>
#                    </fieldset>
#                    <fieldset class="actions">
#                     <div class="row">
#                      <input class="button" id="login_submit" role="button" type="submit"/>
#                      <label class="login-submit-substitute">
#                       LOG IN
#                      </label>
#                     </div>
#                     <div class="persist row">
#                      <div class="content-center">
#                       <input checked="checked" id="login_persist" name="persist" type="checkbox"/>
#                       <label class="persist-login" for="login_persist">
#                        Keep me logged in
#                       </label>
#                      </div>
#                     </div>
#                     <div class="row">
#                      <div class="content-center">
#                       <a href="https://users.premierleague.com/PremierUser/login/reset_password.html">
#                        Forgotten password?
#                       </a>
#                       <span class="seperator">
#                        |
#                       </span>
#                       <a href="https://users.premierleague.com/PremierUser/register/index.html">
#                        Register
#                       </a>
#                      </div>
#                     </div>
#                    </fieldset>
#                   </form>
#                  </div>
#                 </div>
#                </div>
#               </div>
#              </div>
#              <div class="parbase persistentsearch">
#               <div class="search-modal" id="search-modal" style="display:none" widget="easyModal">
#                <div class="sitesearch">
#                 <p class="search-title">
#                  SEARCH PREMIERLEAGUE.COM
#                 </p>
#                 <p class="search-intro">
#                  Type in your search then hit enter
#                 </p>
#                 <form action="/en-gb/search.html" method="get">
#                  <fieldset>
#                   <!--  <input  hidden="hidden" type="button" value="Go" onclick="this.form.submit();" class="btn" /> -->
#                   <input class="auto-clear" name="q" placeholder="Search Term" type="text" value="Search term"/>
#                  </fieldset>
#                 </form>
#                 <div class="close">
#                 </div>
#                </div>
#               </div>
#              </div>
#             </div>
#            </div>
#           </div>
#           <div class="section">
#            <div class="parsys megamenu">
#             <script type="text/javascript">
#              $(document).ready(function(){
# 	       $("#megamenu").megamenu({
# 	            dataNodePath      :       "/content/premierleague/en-gb/jcr:content/headersys/megamenu",
# 	            ajaxPath          :       "/content/premierleague-ajax/megamenuajax",
# 	            tvAjaxPath        :       "/content/premierleague-ajax/livetvbymatch",
# 	            isInclude         :       "false",
# 	            dsAjaxAll         :       "/ajax/site-header/ajax-all-matches.json",
# 	            dsAjaxFixtures    :       "/ajax/site-header/ajax-all-fixtures.json",
# 	            dsAjaxResults     :       "/ajax/site-header/ajax-all-results.json",
# 	            dsDefaultAjax     :       "/ajax/site-header.json",
# 	            currentSeason     :       "2014-2015"
# 	        });
#
# 	   });
#             </script>
#             <div class="megamenu" id="megamenu">
#              <!-- The arrows -->
#              <div class="megamenu-arrow megamenu-arrow-next disabled " unselectable="on">
#              </div>
#              <div class="megamenu-arrow megamenu-arrow-prev disabled " unselectable="on">
#              </div>
#              <!-- Wrapper -->
#              <div class="megamenu-wrapper">
#               <div class="megamenu-tape">
#                <ul class="">
#                 <li class="megamenu-match PRE_MATCH first-visible" matchid="755303">
#                  <div class="megamenu-date">
#                   <span field="date" format="ddd d MMM HH:mm" timestamp="1408197600000" widget="localeDate">
#                    Sat 16 Aug 15:00
#                   </span>
#                  </div>
#                  <a href="/en-gb/matchday/matches/2014-2015/epl.html/arsenal-vs-crystal-palace">
#                   <div class="megamenu-matchName">
#                    <span>
#                     ARS
#                    </span>
#                    <span class="megamenu-score">
#                     v
#                    </span>
#                    <span>
#                     CRY
#                    </span>
#                   </div>
#                  </a>
#                  <div class="megamenu-status">
#                   BUY TICKETS
#                   <span class="red-arrow">
#                    &gt;
#                   </span>
#                  </div>
#                  <div class="megamenu-broadcaster">
#                  </div>
#                  <div class="megamenu-venue">
#                   <a href="/en-gb/clubs/profile.stadium.html/arsenal">
#                    Emirates Stadium
#                   </a>
#                  </div>
#                  <div class="megamenu-referee">
#                   <a href="#">
#                   </a>
#                  </div>
#                  <div class="megamenu-highlighted-link matchcentre">
#                  </div>
#                  <div class="megamenu-dynamic-link">
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/arsenal-vs-crystal-palace">
#                     PREVIEW
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.past-meetings.html/arsenal-vs-crystal-palace">
#                     PAST MEETINGS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.teams.html/arsenal-vs-crystal-palace">
#                     TEAMS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/arsenal-vs-crystal-palace">
#                     COMMENTARY
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.match-stats.html/arsenal-vs-crystal-palace">
#                     STATS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/arsenal-vs-crystal-palace">
#                     PHOTOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/arsenal-vs-crystal-palace">
#                     VIDEOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                  </div>
#                  <div class="megamenu-twitter">
#                   <a href="https://twitter.com/search?q=%23ARSCRY">
#                    <span class="megamenu-twitter-btn">
#                     #ARSCRY
#                    </span>
#                   </a>
#                  </div>
#                 </li>
#                 <li class="megamenu-match PRE_MATCH " matchid="755304">
#                  <div class="megamenu-date">
#                   <span field="date" format="ddd d MMM HH:mm" timestamp="1408197600000" widget="localeDate">
#                    Sat 16 Aug 15:00
#                   </span>
#                  </div>
#                  <a href="/en-gb/matchday/matches/2014-2015/epl.html/burnley-vs-chelsea">
#                   <div class="megamenu-matchName">
#                    <span>
#                     BUR
#                    </span>
#                    <span class="megamenu-score">
#                     v
#                    </span>
#                    <span>
#                     CHE
#                    </span>
#                   </div>
#                  </a>
#                  <div class="megamenu-status">
#                   BUY TICKETS
#                   <span class="red-arrow">
#                    &gt;
#                   </span>
#                  </div>
#                  <div class="megamenu-broadcaster">
#                  </div>
#                  <div class="megamenu-venue">
#                   <a href="/en-gb/clubs/profile.stadium.html/burnley">
#                    Turf Moor
#                   </a>
#                  </div>
#                  <div class="megamenu-referee">
#                   <a href="#">
#                   </a>
#                  </div>
#                  <div class="megamenu-highlighted-link matchcentre">
#                  </div>
#                  <div class="megamenu-dynamic-link">
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/burnley-vs-chelsea">
#                     PREVIEW
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.past-meetings.html/burnley-vs-chelsea">
#                     PAST MEETINGS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.teams.html/burnley-vs-chelsea">
#                     TEAMS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/burnley-vs-chelsea">
#                     COMMENTARY
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.match-stats.html/burnley-vs-chelsea">
#                     STATS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/burnley-vs-chelsea">
#                     PHOTOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/burnley-vs-chelsea">
#                     VIDEOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                  </div>
#                  <div class="megamenu-twitter">
#                   <a href="https://twitter.com/search?q=%23BURCHE">
#                    <span class="megamenu-twitter-btn">
#                     #BURCHE
#                    </span>
#                   </a>
#                  </div>
#                 </li>
#                 <li class="megamenu-match PRE_MATCH " matchid="755305">
#                  <div class="megamenu-date">
#                   <span field="date" format="ddd d MMM HH:mm" timestamp="1408197600000" widget="localeDate">
#                    Sat 16 Aug 15:00
#                   </span>
#                  </div>
#                  <a href="/en-gb/matchday/matches/2014-2015/epl.html/leicester-vs-everton">
#                   <div class="megamenu-matchName">
#                    <span>
#                     LEI
#                    </span>
#                    <span class="megamenu-score">
#                     v
#                    </span>
#                    <span>
#                     EVE
#                    </span>
#                   </div>
#                  </a>
#                  <div class="megamenu-status">
#                   BUY TICKETS
#                   <span class="red-arrow">
#                    &gt;
#                   </span>
#                  </div>
#                  <div class="megamenu-broadcaster">
#                  </div>
#                  <div class="megamenu-venue">
#                   <a href="/en-gb/clubs/profile.stadium.html/leicester">
#                    King Power Stadium
#                   </a>
#                  </div>
#                  <div class="megamenu-referee">
#                   <a href="#">
#                   </a>
#                  </div>
#                  <div class="megamenu-highlighted-link matchcentre">
#                  </div>
#                  <div class="megamenu-dynamic-link">
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/leicester-vs-everton">
#                     PREVIEW
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.past-meetings.html/leicester-vs-everton">
#                     PAST MEETINGS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.teams.html/leicester-vs-everton">
#                     TEAMS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/leicester-vs-everton">
#                     COMMENTARY
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.match-stats.html/leicester-vs-everton">
#                     STATS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/leicester-vs-everton">
#                     PHOTOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/leicester-vs-everton">
#                     VIDEOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                  </div>
#                  <div class="megamenu-twitter">
#                   <a href="https://twitter.com/search?q=%23LEIEVE">
#                    <span class="megamenu-twitter-btn">
#                     #LEIEVE
#                    </span>
#                   </a>
#                  </div>
#                 </li>
#                 <li class="megamenu-match PRE_MATCH " matchid="755306">
#                  <div class="megamenu-date">
#                   <span field="date" format="ddd d MMM HH:mm" timestamp="1408197600000" widget="localeDate">
#                    Sat 16 Aug 15:00
#                   </span>
#                  </div>
#                  <a href="/en-gb/matchday/matches/2014-2015/epl.html/liverpool-vs-southampton">
#                   <div class="megamenu-matchName">
#                    <span>
#                     LIV
#                    </span>
#                    <span class="megamenu-score">
#                     v
#                    </span>
#                    <span>
#                     SOU
#                    </span>
#                   </div>
#                  </a>
#                  <div class="megamenu-status">
#                   BUY TICKETS
#                   <span class="red-arrow">
#                    &gt;
#                   </span>
#                  </div>
#                  <div class="megamenu-broadcaster">
#                  </div>
#                  <div class="megamenu-venue">
#                   <a href="/en-gb/clubs/profile.stadium.html/liverpool">
#                    Anfield
#                   </a>
#                  </div>
#                  <div class="megamenu-referee">
#                   <a href="#">
#                   </a>
#                  </div>
#                  <div class="megamenu-highlighted-link matchcentre">
#                  </div>
#                  <div class="megamenu-dynamic-link">
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/liverpool-vs-southampton">
#                     PREVIEW
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.past-meetings.html/liverpool-vs-southampton">
#                     PAST MEETINGS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.teams.html/liverpool-vs-southampton">
#                     TEAMS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/liverpool-vs-southampton">
#                     COMMENTARY
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.match-stats.html/liverpool-vs-southampton">
#                     STATS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/liverpool-vs-southampton">
#                     PHOTOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/liverpool-vs-southampton">
#                     VIDEOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                  </div>
#                  <div class="megamenu-twitter">
#                   <a href="https://twitter.com/search?q=%23LIVSOU">
#                    <span class="megamenu-twitter-btn">
#                     #LIVSOU
#                    </span>
#                   </a>
#                  </div>
#                 </li>
#                 <li class="megamenu-match PRE_MATCH " matchid="755307">
#                  <div class="megamenu-date">
#                   <span field="date" format="ddd d MMM HH:mm" timestamp="1408197600000" widget="localeDate">
#                    Sat 16 Aug 15:00
#                   </span>
#                  </div>
#                  <a href="/en-gb/matchday/matches/2014-2015/epl.html/man-utd-vs-swansea">
#                   <div class="megamenu-matchName">
#                    <span>
#                     MUN
#                    </span>
#                    <span class="megamenu-score">
#                     v
#                    </span>
#                    <span>
#                     SWA
#                    </span>
#                   </div>
#                  </a>
#                  <div class="megamenu-status">
#                   BUY TICKETS
#                   <span class="red-arrow">
#                    &gt;
#                   </span>
#                  </div>
#                  <div class="megamenu-broadcaster">
#                  </div>
#                  <div class="megamenu-venue">
#                   <a href="/en-gb/clubs/profile.stadium.html/man-utd">
#                    Old Trafford
#                   </a>
#                  </div>
#                  <div class="megamenu-referee">
#                   <a href="#">
#                   </a>
#                  </div>
#                  <div class="megamenu-highlighted-link matchcentre">
#                  </div>
#                  <div class="megamenu-dynamic-link">
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/man-utd-vs-swansea">
#                     PREVIEW
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.past-meetings.html/man-utd-vs-swansea">
#                     PAST MEETINGS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="show">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.teams.html/man-utd-vs-swansea">
#                     TEAMS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/man-utd-vs-swansea">
#                     COMMENTARY
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.match-stats.html/man-utd-vs-swansea">
#                     STATS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/man-utd-vs-swansea">
#                     PHOTOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                   <div class="hide">
#                    <a href="/en-gb/matchday/matches/2014-2015/epl.html/man-utd-vs-swansea">
#                     VIDEOS
#                     <span class="red-arrow">
#                      &gt;
#                     </span>
#                    </a>
#                   </div>
#                  </div>
#                  <div class="megamenu-twitter">
#                   <a href="https://twitter.com/search?q=%23MUNSWA">
#                    <span class="megamenu-twitter-btn">
#                     #MUNSWA
#                    </span>
#                   </a>
#                  </div>
#                 </li>
#                 <li class="megamenu-match PRE_MATCH " matchid="755308">
#                  <div class="megamenu-date">
#                   <span field="date" format="ddd d MMM HH:mm" timestamp="1408197600000" widget="localeDate">
#                    Sat 16 Aug 15:00
#                   </span>
#                  </div>
#                  <a href="/en-gb/matchday/matches/2014-2015/epl.html/newcastle-vs-man-city">
#                   <div class="megamenu-matchName">
#                    <span>
#                     NEW
#                    </span>
#                    <span class="megamenu-score">
#                     v
#                    </span>
#                    <span>
#                     MCI
#                    </span>
#                   </div>
#                  </a>
#                  <div class="megamenu-status">
#                   BUY TICKETS
#                   <span class="red-arrow">
#                    &gt;
#                   </span>
#                  </div>
#                  <div class="megamenu-broadcaster">
#                  </div>
#                  <div class="megamenu-venue">
#                   <a href="/en-gb/clubs/profile.stadium.html/newcastle">
#                    St. James' Park
#                   </a>
#                  </div>
# ...
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/man-utd-vs-chelsea">
#             Man Utd v Chelsea
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/man-utd">
#             Old Trafford
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755385">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755386.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/qpr-vs-aston-villa">
#             QPR v Aston Villa
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/qpr">
#             Loftus Road Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755386">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755387.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/southampton-vs-stoke">
#             Southampton v Stoke
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/southampton">
#             St. Mary's Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755387">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755388.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/sunderland-vs-arsenal">
#             Sunderland v Arsenal
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/sunderland">
#             Stadium of Light
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755388">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755389.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/swansea-vs-leicester">
#             Swansea v Leicester
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/swansea">
#             Liberty Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755389">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755390.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/spurs-vs-newcastle">
#             Spurs v Newcastle
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/spurs">
#             White Hart Lane
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755390">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755391.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/west-brom-vs-crystal-palace">
#             West Brom v Crystal Palace
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/west-brom">
#             The Hawthorns
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755391">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755392.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/west-ham-vs-man-city">
#             West Ham v Man City
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/west-ham">
#             Boleyn Ground
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755392">
#           </td>
#          </tr>
#         </table>
#         <table class="contentTable">
#          <tr>
#           <th colspan="6">
#            Saturday 1 November 2014
#            <span class="masthead" title="Barclays Premier League">
#            </span>
#           </th>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755393.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/arsenal-vs-burnley">
#             Arsenal v Burnley
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/arsenal">
#             Emirates Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755393">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755394.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/aston-villa-vs-spurs">
#             Aston Villa v Spurs
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/aston-villa">
#             Villa Park
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755394">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755395.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/chelsea-vs-qpr">
#             Chelsea v QPR
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/chelsea">
#             Stamford Bridge
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755395">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755396.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/crystal-palace-vs-sunderland">
#             Crystal Palace v Sunderland
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/crystal-palace">
#             Selhurst Park
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755396">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755397.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/everton-vs-swansea">
#             Everton v Swansea
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/everton">
#             Goodison Park
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755397">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755398.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/hull-vs-southampton">
#             Hull v Southampton
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/hull">
#             The KC Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755398">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755399.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/leicester-vs-west-brom">
#             Leicester v West Brom
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/leicester">
#             King Power Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755399">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755400.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/man-city-vs-man-utd">
#             Man City v Man Utd
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/man-city">
#             Etihad Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755400">
#           </td>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755401.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/newcastle-vs-liverpool">
#             Newcastle v Liverpool
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/newcastle">
#             St. James' Park
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755401">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755402.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/stoke-vs-west-ham">
#             Stoke v West Ham
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/stoke">
#             Britannia Stadium
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755402">
#           </td>
#          </tr>
#         </table>
#         <table class="contentTable">
#          <tr>
#           <th colspan="6">
#            Saturday 8 November 2014
#            <span class="masthead" title="Barclays Premier League">
#            </span>
#           </th>
#          </tr>
#          <tr class="alt">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755403.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/burnley-vs-hull">
#             Burnley v Hull
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb/clubs/profile.stadium.html/burnley">
#             Turf Moor
#            </a>
#           </td>
#           <td class="tickets">
#           </td>
#           <td class="broadcasters" match="755403">
#           </td>
#          </tr>
#          <tr class="">
#           <td class="calendar">
#            <a href="/content/premierleague-ical/matchevent.html/755404.ics">
#             <img alt="" class="calIcon" src="/etc/designs/premierleague/images/shim.gif"/>
#            </a>
#           </td>
#           <td class="time">
#            15:00
#           </td>
#           <td class="clubs">
#            <a href="/en-gb/matchday/matches/2014-2015/epl.match-preview.html/liverpool-vs-chelsea">
#             Liverpool v Chelsea
#            </a>
#           </td>
#           <td class="location">
#            <a href="/en-gb">
#            </a>
#           </td>
#          </tr>
#         </table>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>

# %% [markdown]
# This loop extracts all the fixture information. For each table tag, find the relevant match information. This information should be inserted into a DB for further analysis. Find out why enumerate doesn't work on a BS4 object. This needs to be optimized.

# %%
def connect() :
	db_params = {
		'user' : "root",
		'password' : "",
		'host' : "localhost",
		'port' : 3306,
		'database' : "Twitter",
		'charset' : 'utf8',
		'collation' : 'utf8_general_ci',
		'buffered' : True
	}
	return sql.connect(**db_params)

# %%
conn = connect()
cursor = conn.cursor()

# %%
def formatDate(date):
    return parser.parse(date)

# %%
def insert_premier_league_fixtures(superclass = "Soccer", league = "Premier League") : 
    
    for table in soup.find_all("table", "contentTable"):

        home, away = [],[]    
        dates = table.find_all("th")
        times = table.find_all("td", "time")
        teams = table.find_all("td", "clubs")
        stadiums = table.find_all("td", "location")
        
        count = 0
        for date in dates:
            for time in times:
                dt = formatDate(date.get_text() + times[count].get_text())
                home, sep, away = teams[count].get_text("|", strip=True).rpartition(" v ")
                #query = "INSERT INTO fixtures(date_time, superclass, league, home_team, away_team, venue, result) VALUES(%s, %s, %s, %s, %s, %s, %s)"
                values = [dt, superclass, league, home, away, stadium[count].get_text("|", strip=True), "0-0"]
                try :
                    cursor.execute(query, values)
                    conn.commit()
                except sql.Error as err :
                    print err
                print dt , 'Soccer' + ", " "Premier League" + ", " + home + " v " + away + ", " + stadium[count].get_text("|", strip=True)
                count = count + 1

# %%
insert_premier_league_fixtures()
# Out:
# 1062 (23000): Duplicate entry '2014-01-11 12:45:00-Hull' for key 'PRIMARY'
# 2014-01-11 12:45:00 Soccer, Premier League, Hull v Chelsea, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-11 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-01-11 15:00:00 Soccer, Premier League, Cardiff v West Ham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-01-11 15:00:00-Everton' for key 'PRIMARY'
# 2014-01-11 15:00:00 Soccer, Premier League, Everton v Norwich, The KC Stadium
# 1062 (23000): Duplicate entry '2014-01-11 15:00:00-Fulham' for key 'PRIMARY'
# 2014-01-11 15:00:00 Soccer, Premier League, Fulham v Sunderland, Anfield
# 1062 (23000): Duplicate entry '2014-01-11 15:00:00-Southampton' for key 'PRIMARY'
# 2014-01-11 15:00:00 Soccer, Premier League, Southampton v West Brom, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-01-11 15:00:00-Spurs' for key 'PRIMARY'
# 2014-01-11 15:00:00 Soccer, Premier League, Spurs v Crystal Palace, Carrow Road
# 1062 (23000): Duplicate entry '2014-01-11 17:30:00-Man Utd' for key 'PRIMARY'
# 2014-01-11 17:30:00 Soccer, Premier League, Man Utd v Swansea, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-01-12 14:05:00-Newcastle' for key 'PRIMARY'
# 2014-01-12 14:05:00 Soccer, Premier League, Newcastle v Man City, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-12 16:10:00-Stoke' for key 'PRIMARY'
# 2014-01-12 16:10:00 Soccer, Premier League, Stoke v Liverpool, Craven Cottage
# 1062 (23000): Duplicate entry '2014-01-13 20:00:00-Aston Villa' for key 'PRIMARY'
# 2014-01-13 20:00:00 Soccer, Premier League, Aston Villa v Arsenal, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-18 12:45:00-Sunderland' for key 'PRIMARY'
# 2014-01-18 12:45:00 Soccer, Premier League, Sunderland v Southampton, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-18 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-01-18 15:00:00 Soccer, Premier League, Arsenal v Fulham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-01-18 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-01-18 15:00:00 Soccer, Premier League, Crystal Palace v Stoke, The KC Stadium
# 1062 (23000): Duplicate entry '2014-01-18 15:00:00-Man City' for key 'PRIMARY'
# 2014-01-18 15:00:00 Soccer, Premier League, Man City v Cardiff, Anfield
# 1062 (23000): Duplicate entry '2014-01-18 15:00:00-Norwich' for key 'PRIMARY'
# 2014-01-18 15:00:00 Soccer, Premier League, Norwich v Hull, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-01-18 15:00:00-West Ham' for key 'PRIMARY'
# 2014-01-18 15:00:00 Soccer, Premier League, West Ham v Newcastle, Carrow Road
# 1062 (23000): Duplicate entry '2014-01-18 17:30:00-Liverpool' for key 'PRIMARY'
# 2014-01-18 17:30:00 Soccer, Premier League, Liverpool v Aston Villa, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-01-19 13:30:00-Swansea' for key 'PRIMARY'
# 2014-01-19 13:30:00 Soccer, Premier League, Swansea v Spurs, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-19 16:00:00-Chelsea' for key 'PRIMARY'
# 2014-01-19 16:00:00 Soccer, Premier League, Chelsea v Man Utd, Craven Cottage
# 1062 (23000): Duplicate entry '2014-01-20 20:00:00-West Brom' for key 'PRIMARY'
# 2014-01-20 20:00:00 Soccer, Premier League, West Brom v Everton, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-28 19:45:00-Man Utd' for key 'PRIMARY'
# 2014-01-28 19:45:00 Soccer, Premier League, Man Utd v Cardiff, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-28 19:45:00-Norwich' for key 'PRIMARY'
# 2014-01-28 19:45:00 Soccer, Premier League, Norwich v Newcastle, Craven Cottage
# 1062 (23000): Duplicate entry '2014-01-28 19:45:00-Southampton' for key 'PRIMARY'
# 2014-01-28 19:45:00 Soccer, Premier League, Southampton v Arsenal, The KC Stadium
# 1062 (23000): Duplicate entry '2014-01-28 19:45:00-Sunderland' for key 'PRIMARY'
# 2014-01-28 19:45:00 Soccer, Premier League, Sunderland v Stoke, Anfield
# 1062 (23000): Duplicate entry '2014-01-28 19:45:00-Swansea' for key 'PRIMARY'
# 2014-01-28 19:45:00 Soccer, Premier League, Swansea v Fulham, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-01-28 20:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-01-28 20:00:00 Soccer, Premier League, Crystal Palace v Hull, Carrow Road
# 1062 (23000): Duplicate entry '2014-01-28 20:00:00-Liverpool' for key 'PRIMARY'
# 2014-01-28 20:00:00 Soccer, Premier League, Liverpool v Everton, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-01-29 19:45:00-Aston Villa' for key 'PRIMARY'
# 2014-01-29 19:45:00 Soccer, Premier League, Aston Villa v West Brom, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-01-29 19:45:00-Chelsea' for key 'PRIMARY'
# 2014-01-29 19:45:00 Soccer, Premier League, Chelsea v West Ham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-01-29 19:45:00-Spurs' for key 'PRIMARY'
# 2014-01-29 19:45:00 Soccer, Premier League, Spurs v Man City, The KC Stadium
# 1062 (23000): Duplicate entry '2014-02-01 12:45:00-Newcastle' for key 'PRIMARY'
# 2014-02-01 12:45:00 Soccer, Premier League, Newcastle v Sunderland, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-01 12:45:00-West Ham' for key 'PRIMARY'
# 2014-02-01 12:45:00 Soccer, Premier League, West Ham v Swansea, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-01 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-02-01 15:00:00 Soccer, Premier League, Cardiff v Norwich, The KC Stadium
# 1062 (23000): Duplicate entry '2014-02-01 15:00:00-Everton' for key 'PRIMARY'
# 2014-02-01 15:00:00 Soccer, Premier League, Everton v Aston Villa, Anfield
# 1062 (23000): Duplicate entry '2014-02-01 15:00:00-Fulham' for key 'PRIMARY'
# 2014-02-01 15:00:00 Soccer, Premier League, Fulham v Southampton, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-02-01 15:00:00-Hull' for key 'PRIMARY'
# 2014-02-01 15:00:00 Soccer, Premier League, Hull v Spurs, Carrow Road
# 1062 (23000): Duplicate entry '2014-02-01 15:00:00-Stoke' for key 'PRIMARY'
# 2014-02-01 15:00:00 Soccer, Premier League, Stoke v Man Utd, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-02-02 13:30:00-West Brom' for key 'PRIMARY'
# 2014-02-02 13:30:00 Soccer, Premier League, West Brom v Liverpool, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-02 16:00:00-Arsenal' for key 'PRIMARY'
# 2014-02-02 16:00:00 Soccer, Premier League, Arsenal v Crystal Palace, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-03 20:00:00-Man City' for key 'PRIMARY'
# 2014-02-03 20:00:00 Soccer, Premier League, Man City v Chelsea, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-08 12:45:00-Liverpool' for key 'PRIMARY'
# 2014-02-08 12:45:00 Soccer, Premier League, Liverpool v Arsenal, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-08 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-02-08 15:00:00 Soccer, Premier League, Aston Villa v West Ham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-08 15:00:00-Chelsea' for key 'PRIMARY'
# 2014-02-08 15:00:00 Soccer, Premier League, Chelsea v Newcastle, The KC Stadium
# 1062 (23000): Duplicate entry '2014-02-08 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-02-08 15:00:00 Soccer, Premier League, Crystal Palace v West Brom, Anfield
# 1062 (23000): Duplicate entry '2014-02-08 15:00:00-Norwich' for key 'PRIMARY'
# 2014-02-08 15:00:00 Soccer, Premier League, Norwich v Man City, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-02-08 15:00:00-Southampton' for key 'PRIMARY'
# 2014-02-08 15:00:00 Soccer, Premier League, Southampton v Stoke, Carrow Road
# 1062 (23000): Duplicate entry '2014-02-08 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-02-08 15:00:00 Soccer, Premier League, Sunderland v Hull, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-02-08 17:30:00-Swansea' for key 'PRIMARY'
# 2014-02-08 17:30:00 Soccer, Premier League, Swansea v Cardiff, Stadium of Light
# 1062 (23000): Duplicate entry '2014-02-09 13:30:00-Spurs' for key 'PRIMARY'
# 2014-02-09 13:30:00 Soccer, Premier League, Spurs v Everton, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-09 16:00:00-Man Utd' for key 'PRIMARY'
# 2014-02-09 16:00:00 Soccer, Premier League, Man Utd v Fulham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-11 19:45:00-Cardiff' for key 'PRIMARY'
# 2014-02-11 19:45:00 Soccer, Premier League, Cardiff v Aston Villa, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-11 19:45:00-Hull' for key 'PRIMARY'
# 2014-02-11 19:45:00
# Soccer, Premier League, Hull v Southampton, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-11 19:45:00-West Ham' for key 'PRIMARY'
# 2014-02-11 19:45:00 Soccer, Premier League, West Ham v Norwich, The KC Stadium
# 1062 (23000): Duplicate entry '2014-02-11 20:00:00-West Brom' for key 'PRIMARY'
# 2014-02-11 20:00:00 Soccer, Premier League, West Brom v Chelsea, Anfield
# 1062 (23000): Duplicate entry '2014-02-12 19:45:00-Arsenal' for key 'PRIMARY'
# 2014-02-12 19:45:00 Soccer, Premier League, Arsenal v Man Utd, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-12 19:45:00-Everton' for key 'PRIMARY'
# 2014-02-12 19:45:00 Soccer, Premier League, Everton v Crystal Palace, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-12 19:45:00-Man City' for key 'PRIMARY'
# 2014-02-12 19:45:00 Soccer, Premier League, Man City v Sunderland, The KC Stadium
# 1062 (23000): Duplicate entry '2014-02-12 19:45:00-Newcastle' for key 'PRIMARY'
# 2014-02-12 19:45:00 Soccer, Premier League, Newcastle v Spurs, Anfield
# 1062 (23000): Duplicate entry '2014-02-12 19:45:00-Stoke' for key 'PRIMARY'
# 2014-02-12 19:45:00 Soccer, Premier League, Stoke v Swansea, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-02-12 20:00:00-Fulham' for key 'PRIMARY'
# 2014-02-12 20:00:00 Soccer, Premier League, Fulham v Liverpool, Carrow Road
# 1062 (23000): Duplicate entry '2014-02-22 12:45:00-Chelsea' for key 'PRIMARY'
# 2014-02-22 12:45:00 Soccer, Premier League, Chelsea v Everton, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-22 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-02-22 15:00:00 Soccer, Premier League, Arsenal v Sunderland, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-22 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-02-22 15:00:00 Soccer, Premier League, Cardiff v Hull, The KC Stadium
# 1062 (23000): Duplicate entry '2014-02-22 15:00:00-Man City' for key 'PRIMARY'
# 2014-02-22 15:00:00 Soccer, Premier League, Man City v Stoke, Anfield
# 1062 (23000): Duplicate entry '2014-02-22 15:00:00-West Brom' for key 'PRIMARY'
# 2014-02-22 15:00:00 Soccer, Premier League, West Brom v Fulham, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-02-22 15:00:00-West Ham' for key 'PRIMARY'
# 2014-02-22 15:00:00 Soccer, Premier League, West Ham v Southampton, Carrow Road
# 1062 (23000): Duplicate entry '2014-02-22 17:30:00-Crystal Palace' for key 'PRIMARY'
# 2014-02-22 17:30:00 Soccer, Premier League, Crystal Palace v Man Utd, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-02-23 13:30:00-Liverpool' for key 'PRIMARY'
# 2014-02-23 13:30:00 Soccer, Premier League, Liverpool v Swansea, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-02-23 13:30:00-Newcastle' for key 'PRIMARY'
# 2014-02-23 13:30:00 Soccer, Premier League, Newcastle v Aston Villa, Craven Cottage
# 1062 (23000): Duplicate entry '2014-02-23 16:00:00-Norwich' for key 'PRIMARY'
# 2014-02-23 16:00:00 Soccer, Premier League, Norwich v Spurs, The KC Stadium
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Aston Villa v Norwich, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Everton' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Everton v West Ham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Fulham' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Fulham v Chelsea, The KC Stadium
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Hull' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Hull v Newcastle, Anfield
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Man Utd' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Man Utd v Man City, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Southampton' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Southampton v Liverpool, Carrow Road
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Stoke' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Stoke v Arsenal, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-03-01 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-03-01 15:00:00 Soccer, Premier League, Sunderland v West Brom, Stadium of Light
# 1062 (23000): Duplicate entry '2014-03-02 15:00:00-Swansea' for key 'PRIMARY'
# 2014-03-02 15:00:00 Soccer, Premier League, Swansea v Crystal Palace, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-03-02 15:00:00-Spurs' for key 'PRIMARY'
# 2014-03-02 15:00:00 Soccer, Premier League, Spurs v Cardiff, Craven Cottage
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Arsenal v Swansea, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Cardiff v Fulham, Craven Cottage
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Chelsea' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Chelsea v Spurs, The KC Stadium
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Crystal Palace v Southampton, Anfield
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Liverpool' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Liverpool v Sunderland, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Man City' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Man City v Aston Villa, Carrow Road
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Newcastle' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Newcastle v Everton, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-Norwich' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, Norwich v Stoke, Stadium of Light
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-West Brom' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, West Brom v Man Utd, White Hart Lane
# 1062 (23000): Duplicate entry '2014-03-08 15:00:00-West Ham' for key 'PRIMARY'
# 2014-03-08 15:00:00 Soccer, Premier League, West Ham v Hull, The Hawthorns
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Aston Villa v Chelsea, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Everton' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Everton v Cardiff, Craven Cottage
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Fulham' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Fulham v Newcastle, The KC Stadium
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Hull' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Hull v Man City, Anfield
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Man Utd' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Man Utd v Liverpool, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Southampton' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Southampton v Norwich, Carrow Road
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Stoke' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Stoke v West Ham, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Sunderland v Crystal Palace, Stadium of Light
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Swansea' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Swansea v West Brom, White Hart Lane
# 1062 (23000): Duplicate entry '2014-03-15 15:00:00-Spurs' for key 'PRIMARY'
# 2014-03-15 15:00:00 Soccer, Premier League, Spurs v Arsenal, The Hawthorns
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Aston Villa v Stoke, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Cardiff v Liverpool, Craven Cottage
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Chelsea' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Chelsea v Arsenal, The KC Stadium
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Everton' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Everton v Swansea, Anfield
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Hull' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Hull v West Brom, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Man City' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Man City v Fulham, Carrow Road
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Newcastle' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Newcastle v Crystal Palace, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Norwich' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Norwich v Sunderland, Stadium of Light
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-Spurs' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, Spurs v Southampton, White Hart Lane
# 1062 (23000): Duplicate entry '2014-03-22 15:00:00-West Ham' for key 'PRIMARY'
# 2014-03-22 15:00:00 Soccer, Premier League, West Ham v Man Utd, The Hawthorns
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Arsenal v Man City, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Crystal Palace v Chelsea, Craven Cottage
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Fulham' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Fulham v Everton, The KC Stadium
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Liverpool' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Liverpool v Spurs, Anfield
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Man Utd' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Man Utd v Aston Villa, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Southampton' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Southampton v Newcastle, Carrow Road
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Stoke' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Stoke v Hull, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Sunderland v West Ham, Stadium of Light
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-Swansea' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, Swansea v Norwich, White Hart Lane
# 1062 (23000): Duplicate entry '2014-03-29 15:00:00-West Brom' for key 'PRIMARY'
# 2014-03-29 15:00:00 Soccer, Premier League, West Brom v Cardiff, The Hawthorns
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Aston Villa v Fulham, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Cardiff v Crystal Palace, Craven Cottage
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Chelsea' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Chelsea v Stoke, The KC Stadium
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Everton' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Everton v Arsenal, Anfield
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Hull' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Hull v Swansea, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Man City' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Man City v Southampton, Carrow Road
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Newcastle' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Newcastle v Man Utd, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Norwich' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Norwich v West Brom, Stadium of Light
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-Spurs' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, Spurs v Sunderland, White Hart Lane
# 1062 (23000): Duplicate entry '2014-04-05 15:00:00-West Ham' for key 'PRIMARY'
# 2014-04-05 15:00:00 Soccer, Premier League, West Ham v Liverpool, The Hawthorns
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Arsenal v West Ham, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-04-12 15:00:00
# Soccer, Premier League, Crystal Palace v Aston Villa, Craven Cottage
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Fulham' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Fulham v Norwich, The KC Stadium
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Liverpool' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Liverpool v Man City, Anfield
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Man Utd' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Man Utd v Hull, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Southampton' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Southampton v Cardiff, Carrow Road
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Stoke' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Stoke v Newcastle, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Sunderland v Everton, Stadium of Light
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-Swansea' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, Swansea v Chelsea, White Hart Lane
# 1062 (23000): Duplicate entry '2014-04-12 15:00:00-West Brom' for key 'PRIMARY'
# 2014-04-12 15:00:00 Soccer, Premier League, West Brom v Spurs, The Hawthorns
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Aston Villa v Southampton, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Cardiff v Stoke, Craven Cottage
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Chelsea' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Chelsea v Sunderland, The KC Stadium
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Everton' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Everton v Man Utd, Anfield
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Hull' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Hull v Arsenal, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Man City' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Man City v West Brom, Carrow Road
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Newcastle' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Newcastle v Swansea, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Norwich' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Norwich v Liverpool, Stadium of Light
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-Spurs' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, Spurs v Fulham, White Hart Lane
# 1062 (23000): Duplicate entry '2014-04-19 15:00:00-West Ham' for key 'PRIMARY'
# 2014-04-19 15:00:00 Soccer, Premier League, West Ham v Crystal Palace, The Hawthorns
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Arsenal v Newcastle, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Crystal Palace v Man City, Craven Cottage
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Fulham' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Fulham v Hull, The KC Stadium
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Liverpool' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Liverpool v Chelsea, Anfield
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Man Utd' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Man Utd v Norwich, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Southampton' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Southampton v Everton, Carrow Road
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Stoke' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Stoke v Spurs, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Sunderland v Cardiff, Stadium of Light
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-Swansea' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, Swansea v Aston Villa, White Hart Lane
# 1062 (23000): Duplicate entry '2014-04-26 15:00:00-West Brom' for key 'PRIMARY'
# 2014-04-26 15:00:00 Soccer, Premier League, West Brom v West Ham, The Hawthorns
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Arsenal' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Arsenal v West Brom, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Aston Villa' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Aston Villa v Hull, Craven Cottage
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Chelsea' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Chelsea v Norwich, The KC Stadium
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Crystal Palace' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Crystal Palace v Liverpool, Anfield
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Everton' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Everton v Man City, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Man Utd' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Man Utd v Sunderland, Carrow Road
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Newcastle' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Newcastle v Cardiff, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Stoke' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Stoke v Fulham, Stadium of Light
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-Swansea' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, Swansea v Southampton, White Hart Lane
# 1062 (23000): Duplicate entry '2014-05-03 15:00:00-West Ham' for key 'PRIMARY'
# 2014-05-03 15:00:00 Soccer, Premier League, West Ham v Spurs, The Hawthorns
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Cardiff' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Cardiff v Chelsea, Cardiff City Stadium
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Fulham' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Fulham v Crystal Palace, Craven Cottage
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Hull' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Hull v Everton, The KC Stadium
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Liverpool' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Liverpool v Newcastle, Anfield
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Man City' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Man City v West Ham, Etihad Stadium
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Norwich' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Norwich v Arsenal, Carrow Road
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Southampton' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Southampton v Man Utd, St. Mary's Stadium
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Sunderland' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Sunderland v Swansea, Stadium of Light
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-Spurs' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, Spurs v Aston Villa, White Hart Lane
# 1062 (23000): Duplicate entry '2014-05-11 15:00:00-West Brom' for key 'PRIMARY'
# 2014-05-11 15:00:00 Soccer, Premier League, West Brom v Stoke, The Hawthorns
